# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahchaewon/DSRP_/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/sarahchaewon/DSRP_/refs/heads/main/sampled_passwords.csv'

df = pd.read_csv(url)
df.head()
# Out:
#                         Password  Strength_Level
# 0                   abrocomeLlll               1
# 1       EZ&c%{(1~;eu7a/uUGL&B}%Z               4
# 2  ]|VWl>90|3\]dL~_y*fOQa$5Q~?2q               4
# 3                   accordancyy]               2
# 4                          xjemt               0

# %%
df.info()
